# %% [markdown]
# <a href="https://colab.research.google.com/github/Rmkh77/Iris-Flower-Classification/blob/main/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv("/content/drive/MyDrive/project_hbic/oasis/iris/Iris.csv")

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
plt.plot(iris['Id'], iris["SepalLengthCm"])
plt.plot(iris['Id'], iris["SepalWidthCm"])
plt.xlabel('Id')
plt.ylabel('Sepal lenght and Width')
# Out:
# Text(0, 0.5, 'Sepal lenght and Width')

# %%
plt.plot(iris['Id'], iris["PetalLengthCm"])
plt.plot(iris['Id'], iris["PetalWidthCm"] ,color="green")
plt.xlabel('Id')
plt.ylabel('Petal length and Width')
# Out:
# Text(0, 0.5, 'Petal length and Width')

# %%
iris1=iris.drop("Id",axis=1)
iris1.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
lst1=iris['Species'].value_counts()
tisland=iris['Species'].unique()
plt.pie(lst1,labels=tisland,labeldistance=1,autopct='%1.0f%%')
plt.show()

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import datasets

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
data=datasets.load_iris(as_frame=True)
X=data.data
y=data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=100)
alg_names=[]
alg_val=[]

# %%
def print_scores(alg, y_true, y_pred):
  print(alg)
  acc_score = accuracy_score(y_true, y_pred)
  print("accuracy: ",acc_score)
  alg_val.append(acc_score)
  print(classification_report(y_test,y_pred))

# %%
model=RandomForestClassifier()
m1="RandomForestClassifier"
alg_names.append(m1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print_scores(model,y_test,y_pred)
# Out:
# RandomForestClassifier()
# accuracy:  0.9555555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.91      0.91      0.91        11
#            2       0.94      0.94      0.94        18
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
model=LogisticRegression()
m1="LogisticRegression"
alg_names.append(m1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print_scores(model,y_test,y_pred)
# Out:
# LogisticRegression()
# accuracy:  0.9777777777777777
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.92      1.00      0.96        11
#            2       1.00      0.94      0.97        18
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
model=GaussianNB()
m1="GaussianNB"
alg_names.append(m1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print_scores(model,y_test,y_pred)
# Out:
# GaussianNB()
# accuracy:  0.9555555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.91      0.91      0.91        11
#            2       0.94      0.94      0.94        18
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
model=DecisionTreeClassifier()
m1='DecisionTreeClassifier'
alg_names.append(m1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
print_scores(model,y_test,y_pred)
# Out:
# DecisionTreeClassifier()
# accuracy:  0.9555555555555556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.91      0.91      0.91        11
#            2       0.94      0.94      0.94        18
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
plt.plot(alg_names,alg_val)
plt.xticks(rotation=90,ha='right')
plt.show()

# %% [markdown]
# From the above graph, Logistic Regression shows more accuracy. Hence it is used for prediction

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
testing=model.predict([[3.1,1.5,0.4,0.1]])
if testing==0:
  print("Given Testing Data Point is classified as iris-Setosa")
elif testing==1:
  print("Given Testing Data Point is classified as iris-Versicolor")
elif testing==2:
  print("Given Testing Data Point is classified as iris-Virginica")
# Out:
# Given Testing Data Point is classified as iris-Setosa
